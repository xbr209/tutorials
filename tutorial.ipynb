# %% [markdown]
# ## Introduction to `python` and `jupyter` notebooks

# %% [markdown]
# Import some standard modules into `python`.

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# Read-in a file from the XBR209 `github` directory.

# %%
url = "https://raw.githubusercontent.com/xbr209/tutorials/master/Australian_air_traffic.csv"
dataset = pd.read_csv(url)

dataset
# Out:
#                       Airport  Year  Month     Date  Domestic_Passengers  \
# 0                    Adelaide  2009      1   1/1/09               517632
# 1                    Adelaide  2009      2   1/2/09               466920
# 2                    Adelaide  2009      3   1/3/09               565261
# 3                    Adelaide  2009      4   1/4/09               555522
# 4                    Adelaide  2009      5   1/5/09               517203
# 5                    Adelaide  2009      6   1/6/09               484873
# 6                    Adelaide  2009      7   1/7/09               542166
# 7                    Adelaide  2009      8   1/8/09               538835
# 8                    Adelaide  2009      9   1/9/09               531861
# 9                    Adelaide  2009     10  1/10/09               561466
# 10                   Adelaide  2009     11  1/11/09               531518
# 11                   Adelaide  2009     12  1/12/09               527091
# ...
